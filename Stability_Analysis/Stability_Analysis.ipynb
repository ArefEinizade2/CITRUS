# %%
import torch
import numpy as np
from scipy import sparse
from scipy.sparse.linalg import lobpcg
import scipy.sparse as sp
import tensorly as tl
from tensorly import random
from layers import CITRUS, GTCNN, GTCNN_v2
from Product_Random_Gen_ER_Noisy import Product_Random_Gen_ER, gen_Noisy_graphs
from Product_Random_Gen_ER_Noisy import get_selected_evec_evals
import os
import sys
import argparse
from statistics import mean,stdev
import torch.nn.functional as F
import scipy
import torch_geometric
from torch_geometric.utils import get_laplacian
# sys.path.append(os.path.join(os.path.dirname(__file__), "diffusion_net/")) 
from load_data import get_dataset, split_data, split_data_arxive
from layers import TIDE_net
from funcs import get_optimizer, get_laplacian_selfloop, sparse_mx_to_torch_sparse_tensor
from torch_geometric.nn import GCNConv
from layers import GCN, CGNN
from torch_geometric.utils.convert import from_scipy_sparse_matrix, to_scipy_sparse_matrix
import matplotlib.pyplot as plt
import time

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
def train(epoch, optimizer, model, data, target, train_idx, mass, N, L_list, evals_list, evecs, edge_index):
                
    model.train()
    optimizer.zero_grad()
    
    # Apply the model
    out = model(epoch, data, [], mass=mass, L=L_list, evals=evals_list, evecs=evecs)
    # out = model(data, edge_index)

    # Evaluate loss
    loss = torch.nn.functional.mse_loss(out[train_idx], target[train_idx])   

    loss.backward()    # Back Propagation
    optimizer.step()   # Gardient Descent

    
    return loss

# %%
def train_GCN(epoch, optimizer, model, data, target, train_idx, mass, N, L_list, evals_list, evecs, edge_index):
                
    model.train()
    optimizer.zero_grad()
    
    # Apply the model
    out = model(data, edge_index)

    # Evaluate loss
    loss = torch.nn.functional.mse_loss(out[train_idx], target[train_idx])   

    loss.backward()    # Back Propagation
    optimizer.step()   # Gardient Descent

    
    return loss

# %%
def train_GTCNN(optimizer, model, data, target, train_idx):
                
    model.train()
    optimizer.zero_grad()
    
    # Apply the model
    out = model(data)

    # Evaluate loss
    loss = torch.nn.functional.mse_loss(out[train_idx], target[train_idx])   

    loss.backward(retain_graph=True)    # Back Propagation
    optimizer.step()   # Gardient Descent

    
    return loss

# %%
def train_GCN(epoch, optimizer, model, data, target, train_idx, mass, N, L_list, evals_list, evecs, edge_index):
                
    model.train()
    optimizer.zero_grad()
    
    # Apply the model
    out = model(data, edge_index)

    # Evaluate loss
    loss = torch.nn.functional.mse_loss(out[train_idx], target[train_idx])   

    loss.backward()    # Back Propagation
    optimizer.step()   # Gardient Descent

    
    return loss

# %%
@torch.no_grad()
def test(epoch, model, data, target, train_idx, val_idx, test_idx, mass, N, L_list, evals_list, evecs, edge_index):
    model.eval()            
    losses = []
    with torch.no_grad():    
        out = model(epoch, data, [], mass=mass, L=L_list, evals=evals_list, evecs=evecs)
        # out = model(data, edge_index)
    for mask in [train_idx, val_idx, test_idx]:
        loss = torch.nn.functional.mse_loss(out[mask], target[mask]) 
        losses.append(loss)
    return losses

# %%
@torch.no_grad()
def test_GTCNN(model, data, target, train_idx, val_idx, test_idx):
    model.eval()            
    losses = []
    with torch.no_grad():    
        out = model(data)
    for mask in [train_idx, val_idx, test_idx]:
        loss = torch.nn.functional.mse_loss(out[mask], target[mask]) 
        losses.append(loss)
    return losses

# %%
@torch.no_grad()
def test_GCN(epoch, model, data, target, train_idx, val_idx, test_idx, mass, N, L_list, evals_list, evecs, edge_index):
    model.eval()            
    losses = []
    with torch.no_grad():    
        out = model(data, edge_index)
    for mask in [train_idx, val_idx, test_idx]:
        loss = torch.nn.functional.mse_loss(out[mask], target[mask]) 
        losses.append(loss)
    return losses

# %%
t_total = time.time()

p_ER = [0.1, 0.1]
N = [20, 30]
# F_in = 5
# k = [F_in, F_in, F_in]
k = np.array(N)-2
SNR = torch.inf
SNR = np.inf
test_size = 0.15
val_size = 0.15
Num_layers = 3
t_exp = [2, 3]
t = [t_exp, t_exp, t_exp]
Fea = [6, 5, 4, 2]
iterations = 10
N_block = 2
hidden_f = 2
epochs = 500
lr = 1e-2
weight_decay = False
C_width = 4
k_list = [N[0] - 2, N[1] - 2]

SNR_G1 = [np.inf, 20, 10, 0, -10]
# SNR_G1 = [np.inf, -10]
SNR_G2 = SNR_G1

train_ls = np.zeros((len(SNR_G1), len(SNR_G2), iterations))
val_ls = np.zeros((len(SNR_G1), len(SNR_G2), iterations))
test_ls = np.zeros((len(SNR_G1), len(SNR_G2), iterations))

# %%
for i in range(iterations):
    X, X_noisy, Y, Y_noisy, train_idx, val_idx, test_idx, evals, evecs, L_list, Adj_Cart, Adj_list, L_Cart = Product_Random_Gen_ER(t, p_ER, N, Fea, k, SNR, test_size, val_size).gen_data(Num_layers)
    X = X.to(device)
    X_noisy = X_noisy.to(device)
    Y = Y.to(device)
    Y_noisy = Y_noisy.to(device)
    mass = torch.ones(np.prod(N)).to(device)
    #%%    
    for j in range(len(SNR_G1)):
        for kk in range(len(SNR_G2)):
            SNR_graph_list = [SNR_G1[j], SNR_G2[kk]]
            # SNR_graph_list = [-20, -20]
            L_list_noisy, Adj_list_noisy, Adj_Cart_noisy, L_Cart_noisy  = gen_Noisy_graphs(Adj_list, SNR_graph_list)
            evals, evecs = get_selected_evec_evals(L_list_noisy, k_list)
            
            
            evals_prod, evecs_prod = sparse.linalg.eigs(L_Cart_noisy.numpy(), k=np.prod(N)-2, return_eigenvectors=True)
            evals_prod = torch.tensor(evals_prod.real)
            evals_prod = evals_prod.to(torch.float32).to(device)
            evecs_prod = torch.tensor(evecs_prod.real).to(torch.float32).to(device)        
            
            
            edge_index, edge_weight = from_scipy_sparse_matrix(sparse.coo_matrix(L_Cart_noisy))
            edge_index = edge_index.to(device)
            edge_weight = edge_weight.to(device)
            ## Run mode
            
            Fea_GCN = [Fea[0]]        
            for _ in range(N_block):
                Fea_GCN.append(C_width)
            Fea_GCN.append(Fea[-1])
                
                
            #%############################################ CPGNN ####################################################
            optimizer = 'adamax'    
                    
            model = CITRUS(k=np.prod(k), C_in=Fea[0], C_out=Fea[-1], C_width=C_width, num_nodes = N,
                      N_block = N_block, single_t=False, use_gdc=[],
                        last_activation=lambda x : x,
                        diffusion_method='spectral',
                        with_MLP = True,
                        dropout=True,
                        device = device)
                        
            model = model.to(device)
            
            model_CPGNN = model
                
            parameters = [p for p in model.parameters() if p.requires_grad]
        
            parameters_name= [ name for (name, param) in model.named_parameters() if param.requires_grad]
        
            # Move to device
            mass=torch.ones(np.prod(N)).to(device)
            for ii in range(len(evals)):
                evals[ii] = evals[ii].to(device)
            evecs=evecs.to(device)
        
        
            optimizer = get_optimizer(optimizer, parameters, lr = lr, weight_decay=weight_decay)      
        
        
            total_train=[]
            total_test=[]
            total_val=[]
        
            best_loss = train_loss = val_loss = test_loss = torch.inf
        
            t_CPGNN = time.time()

            for epoch in range(1, epochs + 1):
               
                loss = train(epoch, optimizer, model, X_noisy, Y, train_idx, mass, N=N, L_list=L_list, 
                             evals_list=evals, evecs=evecs, edge_index=edge_index)
                
                tmp_train_loss, tmp_val_loss, tmp_test_loss = test(epoch, model, X_noisy, Y, train_idx, val_idx, test_idx, mass, 
                                                                   N=N, L_list=L_list, 
                                                                   evals_list=evals, evecs=evecs, edge_index=edge_index)
                
                if tmp_val_loss < val_loss:
                    best_epoch = epoch
                    train_loss = tmp_train_loss
                    val_loss = tmp_val_loss
                    test_loss = tmp_test_loss
                      
                
                    total_train.append(train_loss.cpu().numpy())
                    total_val.append(val_loss.cpu().numpy())
                    total_test.append(test_loss.cpu().numpy())
                    
                    # log(Epoch=epoch, Loss=loss, Train=train_acc, Val=val_acc, Test=test_acc)
                    # print(f'CPGNN >>>> iter {i}, SNR_G1: {SNR_G1[j]}, SNR_G2: {SNR_G2[kk]}, Step {epoch}: ' f' Loss: {float(loss):.4f}, Train Loss: {train_loss:.4f}, 'f'Val Loss: {val_loss:.4f}, Test Loss: {test_loss:.4f}')
                    
        
            elapsed = time.time() - t_CPGNN
            print('>>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: %s' % round(elapsed/60,2), ' minutes')

            train_ls[j, kk, i] = train_loss.cpu().numpy()
            val_ls[j, kk, i] = val_loss.cpu().numpy()
            test_ls[j, kk, i] = test_loss.cpu().numpy()
            print(f'CPGNN >>>> iter {i}, SNR_G1: {SNR_G1[j]}, SNR_G2: {SNR_G2[kk]}, Step {epoch}: ' f' Test Loss: {test_loss:.4f}')
            
            
#             plt.figure()
#             plt.close()
#             plt.plot(total_train,'-')
#             plt.plot(total_val,'-')
#             plt.plot(total_test,'-')
#             plt.xlabel('epoch')
#             plt.ylabel('accuracy')
#             plt.legend(['Train','Valid','Test'])
#             plt.title('l: '+str(N_block) + ', MSE: ' + str(np.round(total_test[-1], 2)) + ', SNRs: ' + str(SNR_graph_list))
#             plt.show()
# Out:
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 0, SNR_G1: inf, SNR_G2: inf, Step 500:  Test Loss: 0.0742
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: inf, SNR_G2: 20, Step 500:  Test Loss: 0.1548
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: inf, SNR_G2: 10, Step 500:  Test Loss: 0.1456
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: inf, SNR_G2: 0, Step 500:  Test Loss: 0.2202
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: inf, SNR_G2: -10, Step 500:  Test Loss: 0.2129
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 20, SNR_G2: inf, Step 500:  Test Loss: 0.1893
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 20, SNR_G2: 20, Step 500:  Test Loss: 0.2607
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 20, SNR_G2: 10, Step 500:  Test Loss: 0.2373
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 20, SNR_G2: 0, Step 500:  Test Loss: 0.2819
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 20, SNR_G2: -10, Step 500:  Test Loss: 0.3424
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 0, SNR_G1: 10, SNR_G2: inf, Step 500:  Test Loss: 0.2564
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 10, SNR_G2: 20, Step 500:  Test Loss: 0.2999
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 10, SNR_G2: 10, Step 500:  Test Loss: 0.3014
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 10, SNR_G2: 0, Step 500:  Test Loss: 0.3454
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 10, SNR_G2: -10, Step 500:  Test Loss: 0.3750
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 0, SNR_G2: inf, Step 500:  Test Loss: 0.2891
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 0, SNR_G1: 0, SNR_G2: 20, Step 500:  Test Loss: 0.2152
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 0, SNR_G1: 0, SNR_G2: 10, Step 500:  Test Loss: 0.3458
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 0, SNR_G2: 0, Step 500:  Test Loss: 0.3756
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: 0, SNR_G2: -10, Step 500:  Test Loss: 0.3619
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: -10, SNR_G2: inf, Step 500:  Test Loss: 0.3066
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: -10, SNR_G2: 20, Step 500:  Test Loss: 0.3581
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: -10, SNR_G2: 10, Step 500:  Test Loss: 0.3394
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 0, SNR_G1: -10, SNR_G2: 0, Step 500:  Test Loss: 0.3689
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 0, SNR_G1: -10, SNR_G2: -10, Step 500:  Test Loss: 0.4372
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: inf, SNR_G2: inf, Step 500:  Test Loss: 0.0275
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: inf, SNR_G2: 20, Step 500:  Test Loss: 0.0448
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: inf, SNR_G2: 10, Step 500:  Test Loss: 0.0456
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: inf, SNR_G2: 0, Step 500:  Test Loss: 0.0926
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: inf, SNR_G2: -10, Step 500:  Test Loss: 0.1239
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 1, SNR_G1: 20, SNR_G2: inf, Step 500:  Test Loss: 0.0321
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: 20, SNR_G2: 20, Step 500:  Test Loss: 0.0339
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 1, SNR_G1: 20, SNR_G2: 10, Step 500:  Test Loss: 0.0543
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 1, SNR_G1: 20, SNR_G2: 0, Step 500:  Test Loss: 0.1074
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 1, SNR_G1: 20, SNR_G2: -10, Step 500:  Test Loss: 0.1331
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: 10, SNR_G2: inf, Step 500:  Test Loss: 0.0426
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 1, SNR_G1: 10, SNR_G2: 20, Step 500:  Test Loss: 0.0618
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: 10, SNR_G2: 10, Step 500:  Test Loss: 0.0543
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: 10, SNR_G2: 0, Step 500:  Test Loss: 0.1030
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: 10, SNR_G2: -10, Step 500:  Test Loss: 0.1343
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: 0, SNR_G2: inf, Step 500:  Test Loss: 0.1006
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: 0, SNR_G2: 20, Step 500:  Test Loss: 0.0775
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 1, SNR_G1: 0, SNR_G2: 10, Step 500:  Test Loss: 0.0888
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 1, SNR_G1: 0, SNR_G2: 0, Step 500:  Test Loss: 0.1267
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: 0, SNR_G2: -10, Step 500:  Test Loss: 0.1755
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 1, SNR_G1: -10, SNR_G2: inf, Step 500:  Test Loss: 0.1095
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: -10, SNR_G2: 20, Step 500:  Test Loss: 0.1241
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: -10, SNR_G2: 10, Step 500:  Test Loss: 0.1581
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: -10, SNR_G2: 0, Step 500:  Test Loss: 0.1501
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 1, SNR_G1: -10, SNR_G2: -10, Step 500:  Test Loss: 0.1776
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: inf, SNR_G2: inf, Step 500:  Test Loss: 0.0275
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 2, SNR_G1: inf, SNR_G2: 20, Step 500:  Test Loss: 0.0344
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: inf, SNR_G2: 10, Step 500:  Test Loss: 0.0863
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: inf, SNR_G2: 0, Step 500:  Test Loss: 0.0821
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 2, SNR_G1: inf, SNR_G2: -10, Step 500:  Test Loss: 0.1565
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 20, SNR_G2: inf, Step 500:  Test Loss: 0.0329
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 20, SNR_G2: 20, Step 500:  Test Loss: 0.0399
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 20, SNR_G2: 10, Step 500:  Test Loss: 0.0431
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 20, SNR_G2: 0, Step 500:  Test Loss: 0.0993
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 20, SNR_G2: -10, Step 500:  Test Loss: 0.1532
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 10, SNR_G2: inf, Step 500:  Test Loss: 0.0612
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 10, SNR_G2: 20, Step 500:  Test Loss: 0.1175
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 10, SNR_G2: 10, Step 500:  Test Loss: 0.1084
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 10, SNR_G2: 0, Step 500:  Test Loss: 0.1230
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 10, SNR_G2: -10, Step 500:  Test Loss: 0.1678
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 0, SNR_G2: inf, Step 500:  Test Loss: 0.0978
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 0, SNR_G2: 20, Step 500:  Test Loss: 0.1138
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 0, SNR_G2: 10, Step 500:  Test Loss: 0.1547
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 0, SNR_G2: 0, Step 500:  Test Loss: 0.2433
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: 0, SNR_G2: -10, Step 500:  Test Loss: 0.2397
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 2, SNR_G1: -10, SNR_G2: inf, Step 500:  Test Loss: 0.2250
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: -10, SNR_G2: 20, Step 500:  Test Loss: 0.2130
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 2, SNR_G1: -10, SNR_G2: 10, Step 500:  Test Loss: 0.2021
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 2, SNR_G1: -10, SNR_G2: 0, Step 500:  Test Loss: 0.2993
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 2, SNR_G1: -10, SNR_G2: -10, Step 500:  Test Loss: 0.2987
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: inf, SNR_G2: inf, Step 500:  Test Loss: 0.0300
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 3, SNR_G1: inf, SNR_G2: 20, Step 500:  Test Loss: 0.0301
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 3, SNR_G1: inf, SNR_G2: 10, Step 500:  Test Loss: 0.0362
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: inf, SNR_G2: 0, Step 500:  Test Loss: 0.0595
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: inf, SNR_G2: -10, Step 500:  Test Loss: 0.0515
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 20, SNR_G2: inf, Step 500:  Test Loss: 0.0330
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 20, SNR_G2: 20, Step 500:  Test Loss: 0.1005
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 20, SNR_G2: 10, Step 500:  Test Loss: 0.1253
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 20, SNR_G2: 0, Step 500:  Test Loss: 0.1489
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 20, SNR_G2: -10, Step 500:  Test Loss: 0.1047
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 10, SNR_G2: inf, Step 500:  Test Loss: 0.1115
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 10, SNR_G2: 20, Step 500:  Test Loss: 0.1052
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 10, SNR_G2: 10, Step 500:  Test Loss: 0.0575
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 3, SNR_G1: 10, SNR_G2: 0, Step 500:  Test Loss: 0.1377
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 10, SNR_G2: -10, Step 500:  Test Loss: 0.1541
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 0, SNR_G2: inf, Step 500:  Test Loss: 0.1277
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 3, SNR_G1: 0, SNR_G2: 20, Step 500:  Test Loss: 0.1254
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 3, SNR_G1: 0, SNR_G2: 10, Step 500:  Test Loss: 0.0959
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 0, SNR_G2: 0, Step 500:  Test Loss: 0.1526
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: 0, SNR_G2: -10, Step 500:  Test Loss: 0.1404
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 3, SNR_G1: -10, SNR_G2: inf, Step 500:  Test Loss: 0.1457
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 3, SNR_G1: -10, SNR_G2: 20, Step 500:  Test Loss: 0.1518
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 3, SNR_G1: -10, SNR_G2: 10, Step 500:  Test Loss: 0.1577
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 3, SNR_G1: -10, SNR_G2: 0, Step 500:  Test Loss: 0.1680
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 3, SNR_G1: -10, SNR_G2: -10, Step 500:  Test Loss: 0.1549
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: inf, SNR_G2: inf, Step 500:  Test Loss: 0.0348
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: inf, SNR_G2: 20, Step 500:  Test Loss: 0.0571
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: inf, SNR_G2: 10, Step 500:  Test Loss: 0.0672
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: inf, SNR_G2: 0, Step 500:  Test Loss: 0.0729
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: inf, SNR_G2: -10, Step 500:  Test Loss: 0.1068
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: 20, SNR_G2: inf, Step 500:  Test Loss: 0.0976
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: 20, SNR_G2: 20, Step 500:  Test Loss: 0.1096
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: 20, SNR_G2: 10, Step 500:  Test Loss: 0.1238
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: 20, SNR_G2: 0, Step 500:  Test Loss: 0.1249
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: 20, SNR_G2: -10, Step 500:  Test Loss: 0.1398
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: 10, SNR_G2: inf, Step 500:  Test Loss: 0.1280
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: 10, SNR_G2: 20, Step 500:  Test Loss: 0.1131
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: 10, SNR_G2: 10, Step 500:  Test Loss: 0.1149
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: 10, SNR_G2: 0, Step 500:  Test Loss: 0.1594
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: 10, SNR_G2: -10, Step 500:  Test Loss: 0.1805
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: 0, SNR_G2: inf, Step 500:  Test Loss: 0.0849
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: 0, SNR_G2: 20, Step 500:  Test Loss: 0.1268
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: 0, SNR_G2: 10, Step 500:  Test Loss: 0.1355
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: 0, SNR_G2: 0, Step 500:  Test Loss: 0.1159
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: 0, SNR_G2: -10, Step 500:  Test Loss: 0.1764
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: -10, SNR_G2: inf, Step 500:  Test Loss: 0.1266
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: -10, SNR_G2: 20, Step 500:  Test Loss: 0.1547
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: -10, SNR_G2: 10, Step 500:  Test Loss: 0.1454
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 4, SNR_G1: -10, SNR_G2: 0, Step 500:  Test Loss: 0.1670
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 4, SNR_G1: -10, SNR_G2: -10, Step 500:  Test Loss: 0.1760
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: inf, SNR_G2: inf, Step 500:  Test Loss: 0.0689
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 5, SNR_G1: inf, SNR_G2: 20, Step 500:  Test Loss: 0.1270
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 5, SNR_G1: inf, SNR_G2: 10, Step 500:  Test Loss: 0.1751
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: inf, SNR_G2: 0, Step 500:  Test Loss: 0.2003
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: inf, SNR_G2: -10, Step 500:  Test Loss: 0.2037
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: 20, SNR_G2: inf, Step 500:  Test Loss: 0.0799
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: 20, SNR_G2: 20, Step 500:  Test Loss: 0.1034
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 5, SNR_G1: 20, SNR_G2: 10, Step 500:  Test Loss: 0.1579
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 5, SNR_G1: 20, SNR_G2: 0, Step 500:  Test Loss: 0.1818
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: 20, SNR_G2: -10, Step 500:  Test Loss: 0.1811
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 5, SNR_G1: 10, SNR_G2: inf, Step 500:  Test Loss: 0.0898
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 5, SNR_G1: 10, SNR_G2: 20, Step 500:  Test Loss: 0.1327
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: 10, SNR_G2: 10, Step 500:  Test Loss: 0.1597
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 5, SNR_G1: 10, SNR_G2: 0, Step 500:  Test Loss: 0.1702
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: 10, SNR_G2: -10, Step 500:  Test Loss: 0.1874
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 5, SNR_G1: 0, SNR_G2: inf, Step 500:  Test Loss: 0.1294
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: 0, SNR_G2: 20, Step 500:  Test Loss: 0.1628
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 5, SNR_G1: 0, SNR_G2: 10, Step 500:  Test Loss: 0.2128
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: 0, SNR_G2: 0, Step 500:  Test Loss: 0.2295
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: 0, SNR_G2: -10, Step 500:  Test Loss: 0.2408
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: -10, SNR_G2: inf, Step 500:  Test Loss: 0.1845
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: -10, SNR_G2: 20, Step 500:  Test Loss: 0.1876
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: -10, SNR_G2: 10, Step 500:  Test Loss: 0.2463
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 5, SNR_G1: -10, SNR_G2: 0, Step 500:  Test Loss: 0.2492
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 5, SNR_G1: -10, SNR_G2: -10, Step 500:  Test Loss: 0.2723
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: inf, SNR_G2: inf, Step 500:  Test Loss: 0.0308
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: inf, SNR_G2: 20, Step 500:  Test Loss: 0.0322
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: inf, SNR_G2: 10, Step 500:  Test Loss: 0.0396
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: inf, SNR_G2: 0, Step 500:  Test Loss: 0.0632
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: inf, SNR_G2: -10, Step 500:  Test Loss: 0.0788
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 20, SNR_G2: inf, Step 500:  Test Loss: 0.0488
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 20, SNR_G2: 20, Step 500:  Test Loss: 0.0491
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 20, SNR_G2: 10, Step 500:  Test Loss: 0.0562
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 20, SNR_G2: 0, Step 500:  Test Loss: 0.0883
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 20, SNR_G2: -10, Step 500:  Test Loss: 0.1292
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 10, SNR_G2: inf, Step 500:  Test Loss: 0.0646
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 10, SNR_G2: 20, Step 500:  Test Loss: 0.0874
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: 10, SNR_G2: 10, Step 500:  Test Loss: 0.1085
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: 10, SNR_G2: 0, Step 500:  Test Loss: 0.1118
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: 10, SNR_G2: -10, Step 500:  Test Loss: 0.1687
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 0, SNR_G2: inf, Step 500:  Test Loss: 0.1241
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 0, SNR_G2: 20, Step 500:  Test Loss: 0.1360
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 0, SNR_G2: 10, Step 500:  Test Loss: 0.1120
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 6, SNR_G1: 0, SNR_G2: 0, Step 500:  Test Loss: 0.1749
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: 0, SNR_G2: -10, Step 500:  Test Loss: 0.2151
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: -10, SNR_G2: inf, Step 500:  Test Loss: 0.1482
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: -10, SNR_G2: 20, Step 500:  Test Loss: 0.1480
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: -10, SNR_G2: 10, Step 500:  Test Loss: 0.1890
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: -10, SNR_G2: 0, Step 500:  Test Loss: 0.2182
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 6, SNR_G1: -10, SNR_G2: -10, Step 500:  Test Loss: 0.1923
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: inf, SNR_G2: inf, Step 500:  Test Loss: 0.0652
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: inf, SNR_G2: 20, Step 500:  Test Loss: 0.0902
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: inf, SNR_G2: 10, Step 500:  Test Loss: 0.1131
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: inf, SNR_G2: 0, Step 500:  Test Loss: 0.2811
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: inf, SNR_G2: -10, Step 500:  Test Loss: 0.3755
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: 20, SNR_G2: inf, Step 500:  Test Loss: 0.0760
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: 20, SNR_G2: 20, Step 500:  Test Loss: 0.1990
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: 20, SNR_G2: 10, Step 500:  Test Loss: 0.2038
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: 20, SNR_G2: 0, Step 500:  Test Loss: 0.2569
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: 20, SNR_G2: -10, Step 500:  Test Loss: 0.2722
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: 10, SNR_G2: inf, Step 500:  Test Loss: 0.1414
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: 10, SNR_G2: 20, Step 500:  Test Loss: 0.1717
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: 10, SNR_G2: 10, Step 500:  Test Loss: 0.3077
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: 10, SNR_G2: 0, Step 500:  Test Loss: 0.3320
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: 10, SNR_G2: -10, Step 500:  Test Loss: 0.4165
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: 0, SNR_G2: inf, Step 500:  Test Loss: 0.1544
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: 0, SNR_G2: 20, Step 500:  Test Loss: 0.1998
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: 0, SNR_G2: 10, Step 500:  Test Loss: 0.3884
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: 0, SNR_G2: 0, Step 500:  Test Loss: 0.3913
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: 0, SNR_G2: -10, Step 500:  Test Loss: 0.3936
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: -10, SNR_G2: inf, Step 500:  Test Loss: 0.1780
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: -10, SNR_G2: 20, Step 500:  Test Loss: 0.1865
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: -10, SNR_G2: 10, Step 500:  Test Loss: 0.3218
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 7, SNR_G1: -10, SNR_G2: 0, Step 500:  Test Loss: 0.2552
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 7, SNR_G1: -10, SNR_G2: -10, Step 500:  Test Loss: 0.3994
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: inf, SNR_G2: inf, Step 500:  Test Loss: 0.0392
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: inf, SNR_G2: 20, Step 500:  Test Loss: 0.0573
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: inf, SNR_G2: 10, Step 500:  Test Loss: 0.0687
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 8, SNR_G1: inf, SNR_G2: 0, Step 500:  Test Loss: 0.0981
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 8, SNR_G1: inf, SNR_G2: -10, Step 500:  Test Loss: 0.1161
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: 20, SNR_G2: inf, Step 500:  Test Loss: 0.1348
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: 20, SNR_G2: 20, Step 500:  Test Loss: 0.0975
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: 20, SNR_G2: 10, Step 500:  Test Loss: 0.0713
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: 20, SNR_G2: 0, Step 500:  Test Loss: 0.1221
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 8, SNR_G1: 20, SNR_G2: -10, Step 500:  Test Loss: 0.1621
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 8, SNR_G1: 10, SNR_G2: inf, Step 500:  Test Loss: 0.1405
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: 10, SNR_G2: 20, Step 500:  Test Loss: 0.1390
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: 10, SNR_G2: 10, Step 500:  Test Loss: 0.1578
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: 10, SNR_G2: 0, Step 500:  Test Loss: 0.2948
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 8, SNR_G1: 10, SNR_G2: -10, Step 500:  Test Loss: 0.2912
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 8, SNR_G1: 0, SNR_G2: inf, Step 500:  Test Loss: 0.2414
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: 0, SNR_G2: 20, Step 500:  Test Loss: 0.2005
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: 0, SNR_G2: 10, Step 500:  Test Loss: 0.1942
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 8, SNR_G1: 0, SNR_G2: 0, Step 500:  Test Loss: 0.1887
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: 0, SNR_G2: -10, Step 500:  Test Loss: 0.2762
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: -10, SNR_G2: inf, Step 500:  Test Loss: 0.2514
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: -10, SNR_G2: 20, Step 500:  Test Loss: 0.2824
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 8, SNR_G1: -10, SNR_G2: 10, Step 500:  Test Loss: 0.2651
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 8, SNR_G1: -10, SNR_G2: 0, Step 500:  Test Loss: 0.2758
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 8, SNR_G1: -10, SNR_G2: -10, Step 500:  Test Loss: 0.2886
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: inf, SNR_G2: inf, Step 500:  Test Loss: 0.0309
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 9, SNR_G1: inf, SNR_G2: 20, Step 500:  Test Loss: 0.0976
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: inf, SNR_G2: 10, Step 500:  Test Loss: 0.1035
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: inf, SNR_G2: 0, Step 500:  Test Loss: 0.1412
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 9, SNR_G1: inf, SNR_G2: -10, Step 500:  Test Loss: 0.1166
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 9, SNR_G1: 20, SNR_G2: inf, Step 500:  Test Loss: 0.0525
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 20, SNR_G2: 20, Step 500:  Test Loss: 0.0846
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 20, SNR_G2: 10, Step 500:  Test Loss: 0.1326
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 9, SNR_G1: 20, SNR_G2: 0, Step 500:  Test Loss: 0.1084
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 20, SNR_G2: -10, Step 500:  Test Loss: 0.1149
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 10, SNR_G2: inf, Step 500:  Test Loss: 0.0706
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 10, SNR_G2: 20, Step 500:  Test Loss: 0.0946
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 10, SNR_G2: 10, Step 500:  Test Loss: 0.1094
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 10, SNR_G2: 0, Step 500:  Test Loss: 0.1312
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 10, SNR_G2: -10, Step 500:  Test Loss: 0.1110
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 0, SNR_G2: inf, Step 500:  Test Loss: 0.1115
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 0, SNR_G2: 20, Step 500:  Test Loss: 0.1647
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 0, SNR_G2: 10, Step 500:  Test Loss: 0.2330
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: 0, SNR_G2: 0, Step 500:  Test Loss: 0.1583
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 9, SNR_G1: 0, SNR_G2: -10, Step 500:  Test Loss: 0.1733
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 9, SNR_G1: -10, SNR_G2: inf, Step 500:  Test Loss: 0.2094
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 9, SNR_G1: -10, SNR_G2: 20, Step 500:  Test Loss: 0.2199
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 9, SNR_G1: -10, SNR_G2: 10, Step 500:  Test Loss: 0.2397
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.04  minutes
# CPGNN >>>> iter 9, SNR_G1: -10, SNR_G2: 0, Step 500:  Test Loss: 0.2399
# >>>>>>>>>>>>>>>>>>>> CPGNN training time, Elapsed: 0.03  minutes
# CPGNN >>>> iter 9, SNR_G1: -10, SNR_G2: -10, Step 500:  Test Loss: 0.2545

# %%
print()

print(f'CPGNN >>>> Average:')
print(np.round(np.mean(test_ls, -1), 2))  
print()


print(f'CPGNN >>>> Standard deviation:')
print(np.round(np.std(test_ls, -1), 2))  
print()
# Out:
# CPGNN >>>> Average:
# [[0.04 0.07 0.09 0.13 0.15]
#  [0.08 0.11 0.12 0.15 0.17]
#  [0.11 0.13 0.15 0.19 0.22]
#  [0.15 0.15 0.2  0.22 0.24]
#  [0.19 0.2  0.23 0.24 0.27]]
#
# CPGNN >>>> Standard deviation:
# [[0.02 0.04 0.04 0.07 0.09]
#  [0.05 0.07 0.06 0.06 0.07]
#  [0.06 0.06 0.08 0.09 0.1 ]
#  [0.06 0.04 0.1  0.09 0.08]
#  [0.06 0.07 0.06 0.06 0.09]]

# %%
np.save('Stability_Results_NEW_Jupyter.npy', test_ls)
a = np.load('Stability_Results_NEW_Jupyter.npy')

# %%
elapsed = time.time() - t_total
print('>>>>>>>>>>>>>>>>>>>> TOTAL time, Elapsed: %s' % round(elapsed/60,2), ' minutes')
# Out:
# >>>>>>>>>>>>>>>>>>>> TOTAL time, Elapsed: 11.2  minutes
